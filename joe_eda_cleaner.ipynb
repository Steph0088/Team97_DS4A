# %%
# Load packages
import os
import pandas as pd
import numpy as np
#import pingouin
#from scipy.stats import chi2_contingency
from IPython.display import Image

# Required for basic python plotting functionality
import matplotlib.pyplot as plt

# Advanced plotting functionality with seaborn
#import seaborn as sns
 
#sns.set(style="whitegrid")  # can set style depending on how you'd like it to look

# increase the size and quality of any plots we produce
#import matplotlib as mpl

#mpl.rcParams["figure.dpi"] = 300

# %%
df = pd.read_csv("data/GVA Data.csv")
df.head(5)
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_id                  239677 non-null  int64
#  1   date                         239677 non-null  object
#  2   state                        239677 non-null  object
#  3   city_or_county               239677 non-null  object
#  4   address                      223180 non-null  object
#  5   n_killed                     239677 non-null  int64
#  6   n_injured                    239677 non-null  int64
#  7   incident_url                 239677 non-null  object
#  8   source_url                   239209 non-null  object
#  9   incident_url_fields_missing  239677 non-null  bool
#  10  congressional_district       227733 non-null  float64
#  11  gun_stolen                   140179 non-null  object
# ...

# %%
best_columns=df.copy()
best_columns=best_columns.drop(columns=['incident_url','source_url',
                                       'incident_url_fields_missing',
                                       'congressional_district','notes',
                                       'participant_age_group','participant_name','sources',
                                       'state_house_district','state_senate_district'])
best_columns.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                gun_stolen                gun_type  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2  0::Unknown||1::Unknown  0::Unknown||1::Unknown
# ...

# %%
best_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   incident_id               239677 non-null  int64
#  1   date                      239677 non-null  object
#  2   state                     239677 non-null  object
#  3   city_or_county            239677 non-null  object
#  4   address                   223180 non-null  object
#  5   n_killed                  239677 non-null  int64
#  6   n_injured                 239677 non-null  int64
#  7   gun_stolen                140179 non-null  object
#  8   gun_type                  140226 non-null  object
#  9   incident_characteristics  239351 non-null  object
#  10  latitude                  231754 non-null  float64
#  11  location_description      42089 non-null   object
#  12  longitude                 231754 non-null  float64
# ...

# %% [markdown]
# best_columns['month_year'] = pd.to_datetime(df['date']).dt.to_period('M')
# best_columns['month_year'] = best_columns['month_year'].astype(str)
# plt.figure(figsize=(20, 8)) # To make it larger
# plt.plot(best_columns['month_year'], best_columns['n_injured']) # The order is plt.plot(x,y)
# plt.title("Line Plot: 2013 - 2018 Gun Violence Injuries")
# plt.xlabel("Date")
# plt.ylabel("Injuries per Month")

# %% [markdown]
# **Total People Killed per State LIST**
#
# **#NORMALIZE THE DEATHS AND INJURIES**
#
# print("Total People Killed per State")
# df.groupby(['state'])['n_killed'].sum().reset_index(name='State').sort_values(by='State', ascending=True)

# %% [markdown]
# stolen = df.groupby(df['gun_stolen']).size()
# stolen

# %% [markdown]
# best_columns_small=best_columns.head()

# %% [markdown]
# #error below - had to stop running
# split_stolen_small = best_columns_small['gun_stolen'].str.split(pat="\|\|",   expand=True)
# split_stolen_small.head()

# %%
best_columns['date']=pd.to_datetime(best_columns['date'])
best_columns.dtypes
# Out:
# incident_id                          int64
# date                        datetime64[ns]
# state                               object
# city_or_county                      object
# address                             object
# n_killed                             int64
# n_injured                            int64
# gun_stolen                          object
# gun_type                            object
# incident_characteristics            object
# latitude                           float64
# location_description                object
# longitude                          float64
# n_guns_involved                    float64
# participant_age                     object
# participant_gender                  object
# participant_relationship            object
# participant_status                  object
# participant_type                    object
# dtype: object

# %%
best_columns.head()
# Out:
#    incident_id       date           state city_or_county  \
# 0       461105 2013-01-01    Pennsylvania     Mckeesport
# 1       460726 2013-01-01      California      Hawthorne
# 2       478855 2013-01-01            Ohio         Lorain
# 3       478925 2013-01-05        Colorado         Aurora
# 4       478959 2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                gun_stolen                gun_type  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2  0::Unknown||1::Unknown  0::Unknown||1::Unknown
# ...

# %%
best_columns_sample=best_columns.sample(500)

# %%
best_columns_head=best_columns.head()

# %%
#error below - had to stop running
split_stolen_small = best_columns_head['gun_stolen'].str.split(pat="\|\|", expand=True)
split_stolen_small
# Out:
#             0           1
# 0         NaN         NaN
# 1         NaN         NaN
# 2  0::Unknown  1::Unknown
# 3         NaN         NaN
# 4  0::Unknown  1::Unknown

# %%
gun_type_split = best_columns_head['gun_type'].str.split(pat="\|\|", expand=True)
gun_type_split
# Out:
#             0           1
# 0         NaN         NaN
# 1         NaN         NaN
# 2  0::Unknown  1::Unknown
# 3         NaN         NaN
# 4  0::Handgun  1::Handgun

# %%
characteristics_split = best_columns_head['incident_characteristics'].str.split(pat="\|\|", expand=True)
characteristics_split
# Out:
#                                            0  \
# 0                     Shot - Wounded/Injured
# 1                     Shot - Wounded/Injured
# 2                     Shot - Wounded/Injured
# 3  Shot - Dead (murder, accidental, suicide)
# 4                     Shot - Wounded/Injured
#
#                                                    1  \
# 0  Mass Shooting (4+ victims injured or killed ex...
# 1          Shot - Dead (murder, accidental, suicide)
# 2          Shot - Dead (murder, accidental, suicide)
# 3                          Officer Involved Incident
# 4          Shot - Dead (murder, accidental, suicide)
#
#                                                    2  \
# 0  Possession (gun(s) found during commission of ...
# 1  Mass Shooting (4+ victims injured or killed ex...
# 2                          Shots Fired - No Injuries
# 3  Officer Involved Shooting - subject/suspect/pe...
# 4                                           Suicide^
#
# ...

# %%
#HOW WOULD I ATTACH THE INCIDENT ID AS WELL?

age_split = best_columns_head['participant_age'].str.split(pat="\|\|", expand=True)
age_split
# Out:
#        0      1      2      3      4
# 0  0::20   None   None   None   None
# 1  0::20   None   None   None   None
# 2  0::25  1::31  2::33  3::34  4::33
# 3  0::29  1::33  2::56  3::33   None
# 4  0::18  1::46  2::14  3::47   None

# %%
gender_split = best_columns_head['participant_gender'].str.split(pat="\|\|", expand=True)
gender_split
# Out:
#            0        1        2          3        4
# 0    0::Male  1::Male  3::Male  4::Female     None
# 1    0::Male     None     None       None     None
# 2    0::Male  1::Male  2::Male    3::Male  4::Male
# 3  0::Female  1::Male  2::Male    3::Male     None
# 4  0::Female  1::Male  2::Male  3::Female     None

# %%
status_split = best_columns_head['participant_status'].str.split(pat="\|\|", expand=True)
status_split
# Out:
#                                 0                      1           2  \
# 0                     0::Arrested             1::Injured  2::Injured
# 1                       0::Killed             1::Injured  2::Injured
# 2  0::Injured, Unharmed, Arrested  1::Unharmed, Arrested   2::Killed
# 3                       0::Killed              1::Killed   2::Killed
# 4                      0::Injured             1::Injured   2::Killed
#
#             3           4
# 0  3::Injured  4::Injured
# 1  3::Injured        None
# 2  3::Injured  4::Injured
# 3   3::Killed        None
# 4   3::Killed        None

# %%
type_split = best_columns_head['participant_type'].str.split(pat="\|\|", expand=True)
type_split
# Out:
#                     0                   1          2                   3  \
# 0           0::Victim           1::Victim  2::Victim           3::Victim
# 1           0::Victim           1::Victim  2::Victim           3::Victim
# 2  0::Subject-Suspect  1::Subject-Suspect  2::Victim           3::Victim
# 3           0::Victim           1::Victim  2::Victim  3::Subject-Suspect
# 4           0::Victim           1::Victim  2::Victim  3::Subject-Suspect
#
#                     4
# 0  4::Subject-Suspect
# 1  4::Subject-Suspect
# 2           4::Victim
# 3                None
# 4                None

# %%
#Of the INCIDENTS & STATES w/ most DEATHS & INJURIES (normalized),
#What % of those incidents SUSPECTS are GENDER & AGE
#How has it changed in those states over time?

# %%
#Which STATES have the highest percentage of SUSPECTS that are also WOMEN?
#Which STATES have the highest percentage of VICTIMS that are also WOMEN?

# %% [markdown]
# **KURT MEETING NOTES - 6/30**
#
# Do more EDA now that we can explore more columns - **In Progress, 7/6**
#
# Strategize how to break down the best columns - **In Progress, 7/6**
#
# Line plot array of major nics states - **Get NICS data into EDA w/ Steph, 7/7**
#
# Heat map of nics and crimes - **w/ Steph, 7/7**
#
# Political map overlay - **w/ Steph, 7/7**
#
# Scrape 2021 - **Completed, Steph 7/5**
#
# Clean them colons - **To Do, 7/11**
