# %% [markdown]
# <a href="https://colab.research.google.com/github/Steph0088/Team97_DS4A/blob/StephanieJ/dataframes_only.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("alldata1.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0       date           state         city  n_killed  n_injured  \
# 0           0   1/1/2013    Pennsylvania   Mckeesport         0          4
# 1           1   1/1/2013      California    Hawthorne         1          3
# 2           2   1/1/2013            Ohio       Lorain         1          3
# 3           3   1/5/2013        Colorado       Aurora         4          0
# 4           4   1/7/2013  North Carolina   Greensboro         2          2
# 5           5   1/7/2013        Oklahoma        Tulsa         4          0
# 6           6  1/19/2013      New Mexico  Albuquerque         5          0
# 7           7  1/21/2013       Louisiana  New Orleans         0          5
# 8           8  1/21/2013      California    Brentwood         0          4
# 9           9  1/23/2013        Maryland    Baltimore         1          6
#
#    incident_id
# 0       461105
# 1       460726
# 2       478855
# 3       478925
# 4       478959
# 5       478948
# 6       479363
# ...

# %%
df_dem=pd.read_csv("CLEAN_demo.csv")

# %%
df_dem.head(10)
# Out:
#    incident_id   age   age_group             type  gender  \
# 0       461105  20.0   Adult 18+           Victim    Male
# 1       460726  20.0   Adult 18+           Victim    Male
# 2       478855  25.0   Adult 18+  Subject-Suspect    Male
# 3       478925  29.0   Adult 18+           Victim  Female
# 4       478959  18.0   Adult 18+           Victim  Female
# 5       478948  23.0   Adult 18+           Victim  Female
# 6       479363  51.0   Adult 18+           Victim    Male
# 7       479374   NaN         NaN           Victim    Male
# 8       479389   NaN  Teen 12-17           Victim    Male
# 9       492151  15.0  Teen 12-17           Victim    Male
#
#                         status
# 0                     Arrested
# 1                       Killed
# 2  Injured, Unharmed, Arrested
# 3                       Killed
# 4                      Injured
# 5                       Killed
# 6                       Killed
# 7                      Injured
# 8                      Injured
# ...

# %%
df_nics=pd.read_csv("nics.csv")

# %%
df_nics
# Out:
#       Unnamed: 0       month          state   permit  permit_recheck  handgun  \
# 0              0  2020-12-01        Alabama  33421.0           505.0  31103.0
# 1              1  2020-12-01         Alaska    441.0             3.0   3658.0
# 2              2  2020-12-01        Arizona   9043.0           846.0  25093.0
# 3              3  2020-12-01       Arkansas   3878.0           900.0  10987.0
# 4              4  2020-12-01     California  26034.0          1788.0  59909.0
# ...          ...         ...            ...      ...             ...      ...
# 5275        5275  2013-01-01       Virginia      0.0             0.0  34636.0
# 5276        5276  2013-01-01     Washington  22087.0             0.0  28505.0
# 5277        5277  2013-01-01  West Virginia    615.0             0.0  12197.0
# 5278        5278  2013-01-01      Wisconsin  15439.0             0.0  25154.0
# 5279        5279  2013-01-01        Wyoming    362.0             0.0   3848.0
#
# ...

# %%
df_law=pd.read_csv("lawbystate.csv")

# %%
df_law.head(10)
# Out:
#    Unnamed: 0    state  year  lawtotal
# 0          22  Alabama  2013        10
# 1          23  Alabama  2014        10
# 2          24  Alabama  2015        10
# 3          25  Alabama  2016        10
# 4          26  Alabama  2017        10
# 5          27  Alabama  2018        10
# 6          28  Alabama  2019        10
# 7          29  Alabama  2020        10
# 8          52   Alaska  2013         3
# 9          53   Alaska  2014         3

# %%
df_rb=pd.read_csv("byRB_normal.csv")

# %%
df_rb
# Out:
#    AVG  year  n_killed  n_injured  lawtotal        pop  normalized_killed  \
# 0    D  2013       130        480       917  166302766           0.078171
# 1    D  2014      4787       9583       945  167172753           2.863505
# 2    D  2015      5171      11655       966  167958705           3.078733
# 3    D  2016      5599      13516       980  168684796           3.319208
# 4    D  2017      5772      13050      1006  169330233           3.408724
# 5    D  2018      5496      12012      1038  169770837           3.237305
# 6    D  2019      5422      12398      1080  170060705           3.188273
# 7    R  2013       160        403       333  149690949           0.106887
# 8    R  2014      6900      11516       333  151128255           4.565658
# 9    R  2015      7458      13569       331  152676458           4.884840
# 10   R  2016      8515      15008       317  154256515           5.520026
# 11   R  2017      8680      15532       310  155655306           5.576424
# ...
